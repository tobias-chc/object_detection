# %% [markdown]
# ## Mount the Google Drive and switch current directory to a directory on the Google Drive.

# %%
try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("We're running Colab")


if IN_COLAB:
  # Mount the Google Drive at mount
  mount='/content/gdrive'
  print("Colab: mounting Google drive on ", mount)

  drive.mount(mount, force_remount=True)

  # Switch to the directory on the Google Drive that you want to use
  import os
  drive_root = mount + "/My Drive/computer_vision/tutorial"
  
  # Create drive_root if it doesn't exist
  create_drive_root = True
  if create_drive_root:
    print("\nColab: making sure ", drive_root, " exists.")
    os.makedirs(drive_root, exist_ok=True)
  
  # Change to the directory
  print("\nColab: Changing directory to ", drive_root)
  # %cd $drive_root
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Mounted at /content/gdrive
#
# Colab: making sure  /content/gdrive/My Drive/computer_vision/tutorial  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/computer_vision/tutorial
# /content/gdrive/My Drive/computer_vision/tutorial

# %%
# Verify we're in the correct working directory
# %pwd
# Out:
# '/content/gdrive/My Drive/computer_vision/tutorial'

# %% [markdown]
# ## Checking GPU status

# %%
#Import needed libraries

import tensorflow as tf

# %%
#Check if GPU is used

my_gpu_device_name = tf.test.gpu_device_name()

if my_gpu_device_name != '/device:GPU:0':
  raise SystemError('GPU not found!')

print(f'Available GPU: {my_gpu_device_name}')
# Out:
# Available GPU: /device:GPU:0

# %%
#Check which GPU

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)

if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-excute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Apr  6 14:57:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    71W / 149W |    145MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
#Check how much memory is still available 

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('low ram')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# low ram

# %% [markdown]
# ## Running the trainning script

# %%
#!python train.py

# %%
# !python predict.py --input dataset/images/image_0697.jpg
# Out:
# [INFO] loading object detector...
# 2022-04-06 14:57:51.680969: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# <PIL.Image.Image image mode=RGB size=600x219 at 0x7FB1F03E8B90>
